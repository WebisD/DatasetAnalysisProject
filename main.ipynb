# %% [markdown]
# # Main file

# %% [markdown]
# ## Modules and Packages

# %%
import import_ipynb
from datasetHandler import Dataset
# Out:
# importing Jupyter notebook from datasetHandler.ipynb

# %% [markdown]
# ## World Happiness Report from 2015

# %%
data2015 = Dataset('datasets/whr_2015.csv')
data2015.printSample()
# Out:
# Quantidade de valores faltantes no dataset:
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# dtype: int64
# Linhas duplicadas:  0
# Número de linhas e colunas:  (158, 7)
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
# 5            7.406                   1.29025  1.31826
# 6            7.378                   1.32944  1.28017
# 7            7.364                   1.33171  1.28907
# 8            7.286                   1.25018  1.31967
# 9            7.284                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811
# 5     0.23351
# 6     0.47610
# 7     0.36262
# 8     0.47501
# 9     0.43562

# %% [markdown]
# ### Relação das variáveis

# %%
data2015.VariableCorrelations()

# %% [markdown]
# ### Regressão linear

# %%
data2015.linearRegression()
data2015.printRegressionGraph()
data2015.R2coefficient()
# Out:
# Coeficiente de determinação R2: 0.8004656793512612

# %% [markdown]
# ### Coeficiente de Spearman

# %%
data2015.spearmanCorrelation()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.795703
# Economy (GDP per Capita)              0.795703                  1.000000
# Family                                0.770038                  0.681042
# Health (Life Expectancy)              0.756960                  0.847096
# Freedom                               0.576352                  0.415421
# Trust (Government Corruption)         0.302397                  0.227675
# Generosity                            0.172463                  0.012482
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.770038                  0.756960  0.576352
# Economy (GDP per Capita)       0.681042                  0.847096  0.415421
# Family                         1.000000                  0.585431  0.528139
# Health (Life Expectancy)       0.585431                  1.000000  0.399800
# Freedom                        0.528139                  0.399800  1.000000
# Trust (Government Corruption)  0.184599                  0.168847  0.463745
# Generosity                     0.146399                  0.110256  0.418458
#
#                                Trust (Government Corruption)  Generosity
# Happiness Score                                     0.302397    0.172463
# Economy (GDP per Capita)                            0.227675    0.012482
# Family                                              0.184599    0.146399
# Health (Life Expectancy)                            0.168847    0.110256
# Freedom                                             0.463745    0.418458
# Trust (Government Corruption)                       1.000000    0.213357
# Generosity                                          0.213357    1.000000

# %% [markdown]
# ### Coeficiente de Pearson

# %%
data2015.pearsonCorrelation()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.780966
# Economy (GDP per Capita)              0.780966                  1.000000
# Family                                0.740605                  0.645299
# Health (Life Expectancy)              0.724200                  0.816478
# Freedom                               0.568211                  0.370300
# Trust (Government Corruption)         0.395199                  0.307885
# Generosity                            0.180319                 -0.010465
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.740605                  0.724200  0.568211
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# Health (Life Expectancy)       0.531104                  1.000000  0.360477
# Freedom                        0.441518                  0.360477  1.000000
# Trust (Government Corruption)  0.205605                  0.248335  0.493524
# Generosity                     0.087513                  0.108335  0.373916
#
#                                Trust (Government Corruption)  Generosity
# Happiness Score                                     0.395199    0.180319
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000

# %% [markdown]
# ## World Happiness Report from 2016

# %%
data2016 = Dataset('datasets/whr_2016.csv')
data2016.printSample()
# Out:
# Quantidade de valores faltantes no dataset:
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# dtype: int64
# Linhas duplicadas:  0
# Número de linhas e colunas:  (157, 7)
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.526                   1.44178  1.16374
# 1            7.509                   1.52733  1.14524
# 2            7.501                   1.42666  1.18326
# 3            7.498                   1.57744  1.12690
# 4            7.413                   1.40598  1.13464
# 5            7.404                   1.44015  1.09610
# 6            7.339                   1.46468  1.02912
# 7            7.334                   1.36066  1.17278
# 8            7.313                   1.44443  1.10476
# 9            7.291                   1.45181  1.08764
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.79504  0.57941                        0.44453
# 1                   0.86303  0.58557                        0.41203
# 2                   0.86733  0.56624                        0.14975
# 3                   0.79579  0.59609                        0.35776
# 4                   0.81091  0.57104                        0.41004
# 5                   0.82760  0.57370                        0.31329
# 6                   0.81231  0.55211                        0.29927
# 7                   0.83096  0.58147                        0.41904
# 8                   0.85120  0.56837                        0.32331
# 9                   0.83121  0.58218                        0.40867
#
#    Generosity
# 0     0.36171
# 1     0.28083
# 2     0.47678
# 3     0.37895
# 4     0.25492
# 5     0.44834
# 6     0.47416
# 7     0.49401
# 8     0.47407
# 9     0.38254

# %% [markdown]
# ### Relação das variáveis

# %%
data2016.VariableCorrelations()

# %% [markdown]
# ### Regressão linear

# %%
data2016.linearRegression()
data2016.printRegressionGraph()
data2016.R2coefficient()
# Out:
# Coeficiente de determinação R2: 0.7206939125540606

# %% [markdown]
# ### Coeficiente de Spearman

# %%
data2016.spearmanCorrelation()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.808486
# Economy (GDP per Capita)              0.808486                  1.000000
# Family                                0.762077                  0.698863
# Health (Life Expectancy)              0.770846                  0.856341
# Freedom                               0.562503                  0.397277
# Trust (Government Corruption)         0.311914                  0.223493
# Generosity                            0.149173                  0.000406
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.762077                  0.770846  0.562503
# Economy (GDP per Capita)       0.698863                  0.856341  0.397277
# Family                         1.000000                  0.618060  0.508152
# Health (Life Expectancy)       0.618060                  1.000000  0.352924
# Freedom                        0.508152                  0.352924  1.000000
# Trust (Government Corruption)  0.177294                  0.168427  0.466232
# Generosity                     0.120647                  0.080010  0.400576
#
#                                Trust (Government Corruption)  Generosity
# Happiness Score                                     0.311914    0.149173
# Economy (GDP per Capita)                            0.223493    0.000406
# Family                                              0.177294    0.120647
# Health (Life Expectancy)                            0.168427    0.080010
# Freedom                                             0.466232    0.400576
# Trust (Government Corruption)                       1.000000    0.252983
# Generosity                                          0.252983    1.000000

# %% [markdown]
# ### Coeficiente de Pearson

# %%
data2016.pearsonCorrelation()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.790322
# Economy (GDP per Capita)              0.790322                  1.000000
# Family                                0.739252                  0.669540
# Health (Life Expectancy)              0.765384                  0.837067
# Freedom                               0.566827                  0.362283
# Trust (Government Corruption)         0.402032                  0.294185
# Generosity                            0.156848                 -0.025531
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.739252                  0.765384  0.566827
# Economy (GDP per Capita)       0.669540                  0.837067  0.362283
# Family                         1.000000                  0.588377  0.450208
# Health (Life Expectancy)       0.588377                  1.000000  0.341199
# Freedom                        0.450208                  0.341199  1.000000
# Trust (Government Corruption)  0.213561                  0.249583  0.502054
# Generosity                     0.089629                  0.075987  0.361751
#
#                                Trust (Government Corruption)  Generosity
# Happiness Score                                     0.402032    0.156848
# Economy (GDP per Capita)                            0.294185   -0.025531
# Family                                              0.213561    0.089629
# Health (Life Expectancy)                            0.249583    0.075987
# Freedom                                             0.502054    0.361751
# Trust (Government Corruption)                       1.000000    0.305930
# Generosity                                          0.305930    1.000000

# %% [markdown]
# ## World Happiness Report from 2017

# %%
data2017 = Dataset('datasets/whr_2017.csv')
data2017.printSample()
# Out:
# Quantidade de valores faltantes no dataset:
# Happiness.Score                  0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# dtype: int64
# Linhas duplicadas:  0
# Número de linhas e colunas:  (155, 7)
#    Happiness.Score  Economy..GDP.per.Capita.    Family  \
# 0            7.537                  1.616463  1.533524
# 1            7.522                  1.482383  1.551122
# 2            7.504                  1.480633  1.610574
# 3            7.494                  1.564980  1.516912
# 4            7.469                  1.443572  1.540247
# 5            7.377                  1.503945  1.428939
# 6            7.316                  1.479204  1.481349
# 7            7.314                  1.405706  1.548195
# 8            7.284                  1.494387  1.478162
# 9            7.284                  1.484415  1.510042
#
#    Health..Life.Expectancy.   Freedom  Generosity  \
# 0                  0.796667  0.635423    0.362012
# 1                  0.792566  0.626007    0.355280
# 2                  0.833552  0.627163    0.475540
# 3                  0.858131  0.620071    0.290549
# 4                  0.809158  0.617951    0.245483
# 5                  0.810696  0.585384    0.470490
# 6                  0.834558  0.611101    0.435540
# 7                  0.816760  0.614062    0.500005
# 8                  0.830875  0.612924    0.385399
# 9                  0.843887  0.601607    0.477699
#
#    Trust..Government.Corruption.
# 0                       0.315964
# 1                       0.400770
# 2                       0.153527
# 3                       0.367007
# 4                       0.382612
# 5                       0.282662
# 6                       0.287372
# 7                       0.382817
# 8                       0.384399
# 9                       0.301184

# %% [markdown]
# ### Relação das variáveis

# %%
data2017.VariableCorrelations()

# %% [markdown]
# ### Regressão linear

# %%
data2017.linearRegression()
data2017.printRegressionGraph()
data2017.R2coefficient()
# Out:
# Coeficiente de determinação R2: 0.8335247266900785

# %% [markdown]
# ### Coeficiente de Spearman

# %%
data2017.spearmanCorrelation()
# Out:
#                                Happiness.Score  Economy..GDP.per.Capita.  \
# Happiness.Score                       1.000000                  0.824992
# Economy..GDP.per.Capita.              0.824992                  1.000000
# Family                                0.773619                  0.711866
# Health..Life.Expectancy.              0.787647                  0.856650
# Freedom                               0.556133                  0.406784
# Generosity                            0.136443                  0.014544
# Trust..Government.Corruption.         0.300966                  0.245625
#
#                                  Family  Health..Life.Expectancy.   Freedom  \
# Happiness.Score                0.773619                  0.787647  0.556133
# Economy..GDP.per.Capita.       0.711866                  0.856650  0.406784
# Family                         1.000000                  0.631133  0.477790
# Health..Life.Expectancy.       0.631133                  1.000000  0.356579
# Freedom                        0.477790                  0.356579  1.000000
# Generosity                     0.081003                  0.075827  0.349625
# Trust..Government.Corruption.  0.202904                  0.175660  0.473072
#
#                                Generosity  Trust..Government.Corruption.
# Happiness.Score                  0.136443                       0.300966
# Economy..GDP.per.Capita.         0.014544                       0.245625
# Family                           0.081003                       0.202904
# Health..Life.Expectancy.         0.075827                       0.175660
# Freedom                          0.349625                       0.473072
# Generosity                       1.000000                       0.230818
# Trust..Government.Corruption.    0.230818                       1.000000

# %% [markdown]
# ### Coeficiente de Pearson

# %%
data2017.pearsonCorrelation()
# Out:
#                                Happiness.Score  Economy..GDP.per.Capita.  \
# Happiness.Score                       1.000000                  0.812469
# Economy..GDP.per.Capita.              0.812469                  1.000000
# Family                                0.752737                  0.688296
# Health..Life.Expectancy.              0.781951                  0.843077
# Freedom                               0.570137                  0.369873
# Generosity                            0.155256                 -0.019011
# Trust..Government.Corruption.         0.429080                  0.350944
#
#                                  Family  Health..Life.Expectancy.   Freedom  \
# Happiness.Score                0.752737                  0.781951  0.570137
# Economy..GDP.per.Capita.       0.688296                  0.843077  0.369873
# Family                         1.000000                  0.612080  0.424966
# Health..Life.Expectancy.       0.612080                  1.000000  0.349827
# Freedom                        0.424966                  0.349827  1.000000
# Generosity                     0.051693                  0.063191  0.316083
# Trust..Government.Corruption.  0.231841                  0.279752  0.499183
#
#                                Generosity  Trust..Government.Corruption.
# Happiness.Score                  0.155256                       0.429080
# Economy..GDP.per.Capita.        -0.019011                       0.350944
# Family                           0.051693                       0.231841
# Health..Life.Expectancy.         0.063191                       0.279752
# Freedom                          0.316083                       0.499183
# Generosity                       1.000000                       0.294159
# Trust..Government.Corruption.    0.294159                       1.000000

# %% [markdown]
# ## World Happiness Report from 2018

# %%
data2018 = Dataset('datasets/whr_2018.csv')
data2018.printSample()
# Out:
# Quantidade de valores faltantes no dataset:
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64
# Linhas duplicadas:  0
# Número de linhas e colunas:  (156, 7)
#    Score  GDP per capita  Social support  Healthy life expectancy  \
# 0  7.632           1.305           1.592                    0.874
# 1  7.594           1.456           1.582                    0.861
# 2  7.555           1.351           1.590                    0.868
# 3  7.495           1.343           1.644                    0.914
# 4  7.487           1.420           1.549                    0.927
# 5  7.441           1.361           1.488                    0.878
# 6  7.328           1.330           1.532                    0.896
# 7  7.324           1.268           1.601                    0.876
# 8  7.314           1.355           1.501                    0.913
# 9  7.272           1.340           1.573                    0.910
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.681       0.202                      0.393
# 1                         0.686       0.286                      0.340
# 2                         0.683       0.284                      0.408
# 3                         0.677       0.353                      0.138
# 4                         0.660       0.256                      0.357
# 5                         0.638       0.333                      0.295
# 6                         0.653       0.321                      0.291
# 7                         0.669       0.365                      0.389
# 8                         0.659       0.285                      0.383
# 9                         0.647       0.361                      0.302

# %% [markdown]
# ### Relação das variáveis

# %%
data2018.VariableCorrelations()

# %% [markdown]
# ### Regressão linear

# %%
data2018.linearRegression()
data2018.printRegressionGraph()
data2018.R2coefficient()
# Out:
# Coeficiente de determinação R2: 0.7008240719570977

# %% [markdown]
# ### Coeficiente de Spearman

# %%
data2018.spearmanCorrelation()
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.822604        0.775751
# GDP per capita                0.822604        1.000000        0.716055
# Social support                0.775751        0.716055        1.000000
# Healthy life expectancy       0.793352        0.862616        0.675091
# Freedom to make life choices  0.534761        0.368499        0.451799
# Generosity                    0.112308       -0.006363        0.044919
# Perceptions of corruption     0.234759        0.219857        0.160472
#
#                               Healthy life expectancy  \
# Score                                        0.793352
# GDP per capita                               0.862616
# Social support                               0.675091
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.370033
# Generosity                                   0.020466
# Perceptions of corruption                    0.213665
#
#                               Freedom to make life choices  Generosity  \
# Score                                             0.534761    0.112308
# GDP per capita                                    0.368499   -0.006363
# Social support                                    0.451799    0.044919
# Healthy life expectancy                           0.370033    0.020466
# Freedom to make life choices                      1.000000    0.348274
# Generosity                                        0.348274    1.000000
# Perceptions of corruption                         0.465174    0.287153
#
#                               Perceptions of corruption
# Score                                          0.234759
# GDP per capita                                 0.219857
# Social support                                 0.160472
# Healthy life expectancy                        0.213665
# Freedom to make life choices                   0.465174
# Generosity                                     0.287153
# Perceptions of corruption                      1.000000

# %% [markdown]
# ### Coeficiente de Pearson

# %%
data2018.pearsonCorrelation()
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.802124        0.745760
# GDP per capita                0.802124        1.000000        0.672080
# Social support                0.745760        0.672080        1.000000
# Healthy life expectancy       0.775814        0.844273        0.667288
# Freedom to make life choices  0.544280        0.332275        0.411087
# Generosity                    0.135825       -0.011241        0.018226
# Perceptions of corruption     0.392151        0.285298        0.226757
#
#                               Healthy life expectancy  \
# Score                                        0.775814
# GDP per capita                               0.844273
# Social support                               0.667288
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.355475
# Generosity                                   0.020751
# Perceptions of corruption                    0.311923
#
#                               Freedom to make life choices  Generosity  \
# Score                                             0.544280    0.135825
# GDP per capita                                    0.332275   -0.011241
# Social support                                    0.411087    0.018226
# Healthy life expectancy                           0.355475    0.020751
# Freedom to make life choices                      1.000000    0.297988
# Generosity                                        0.297988    1.000000
# Perceptions of corruption                         0.466651    0.360302
#
#                               Perceptions of corruption
# Score                                          0.392151
# GDP per capita                                 0.285298
# Social support                                 0.226757
# Healthy life expectancy                        0.311923
# Freedom to make life choices                   0.466651
# Generosity                                     0.360302
# Perceptions of corruption                      1.000000

# %% [markdown]
# ## World Happiness Report from 2019

# %%
data2019 = Dataset('datasets/whr_2019.csv')
data2019.printSample()
# Out:
# Quantidade de valores faltantes no dataset:
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64
# Linhas duplicadas:  0
# Número de linhas e colunas:  (156, 7)
#    Score  GDP per capita  Social support  Healthy life expectancy  \
# 0  7.769           1.340           1.587                    0.986
# 1  7.600           1.383           1.573                    0.996
# 2  7.554           1.488           1.582                    1.028
# 3  7.494           1.380           1.624                    1.026
# 4  7.488           1.396           1.522                    0.999
# 5  7.480           1.452           1.526                    1.052
# 6  7.343           1.387           1.487                    1.009
# 7  7.307           1.303           1.557                    1.026
# 8  7.278           1.365           1.505                    1.039
# 9  7.246           1.376           1.475                    1.016
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# 2                         0.603       0.271                      0.341
# 3                         0.591       0.354                      0.118
# 4                         0.557       0.322                      0.298
# 5                         0.572       0.263                      0.343
# 6                         0.574       0.267                      0.373
# 7                         0.585       0.330                      0.380
# 8                         0.584       0.285                      0.308
# 9                         0.532       0.244                      0.226

# %% [markdown]
# ### Relação das variáveis

# %%
data2019.VariableCorrelations()

# %% [markdown]
# ### Regressão linear

# %%
data2019.linearRegression()
data2019.printRegressionGraph()
data2019.R2coefficient()
# Out:
# Coeficiente de determinação R2: 0.5831750841034311

# %% [markdown]
# ### Coeficiente de Spearman

# %%
data2019.spearmanCorrelation()
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.814483        0.816181
# GDP per capita                0.814483        1.000000        0.768539
# Social support                0.816181        0.768539        1.000000
# Healthy life expectancy       0.807275        0.851513        0.725997
# Freedom to make life choices  0.551974        0.393426        0.449491
# Generosity                    0.070483       -0.041304        0.007695
# Perceptions of corruption     0.217348        0.223203        0.114017
#
#                               Healthy life expectancy  \
# Score                                        0.807275
# GDP per capita                               0.851513
# Social support                               0.725997
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.412906
# Generosity                                  -0.006773
# Perceptions of corruption                    0.165309
#
#                               Freedom to make life choices  Generosity  \
# Score                                             0.551974    0.070483
# GDP per capita                                    0.393426   -0.041304
# Social support                                    0.449491    0.007695
# Healthy life expectancy                           0.412906   -0.006773
# Freedom to make life choices                      1.000000    0.324146
# Generosity                                        0.324146    1.000000
# Perceptions of corruption                         0.403586    0.286171
#
#                               Perceptions of corruption
# Score                                          0.217348
# GDP per capita                                 0.223203
# Social support                                 0.114017
# Healthy life expectancy                        0.165309
# Freedom to make life choices                   0.403586
# Generosity                                     0.286171
# Perceptions of corruption                      1.000000

# %% [markdown]
# ### Coeficiente de Pearson

# %%
data2019.pearsonCorrelation()
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.793883        0.777058
# GDP per capita                0.793883        1.000000        0.754906
# Social support                0.777058        0.754906        1.000000
# Healthy life expectancy       0.779883        0.835462        0.719009
# Freedom to make life choices  0.566742        0.379079        0.447333
# Generosity                    0.075824       -0.079662       -0.048126
# Perceptions of corruption     0.385613        0.298920        0.181899
#
#                               Healthy life expectancy  \
# Score                                        0.779883
# GDP per capita                               0.835462
# Social support                               0.719009
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.390395
# Generosity                                  -0.029511
# Perceptions of corruption                    0.295283
#
#                               Freedom to make life choices  Generosity  \
# Score                                             0.566742    0.075824
# GDP per capita                                    0.379079   -0.079662
# Social support                                    0.447333   -0.048126
# Healthy life expectancy                           0.390395   -0.029511
# Freedom to make life choices                      1.000000    0.269742
# Generosity                                        0.269742    1.000000
# Perceptions of corruption                         0.438843    0.326538
#
#                               Perceptions of corruption
# Score                                          0.385613
# GDP per capita                                 0.298920
# Social support                                 0.181899
# Healthy life expectancy                        0.295283
# Freedom to make life choices                   0.438843
# Generosity                                     0.326538
# Perceptions of corruption                      1.000000
